# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'LBN0SGLPFK3PPF2BRSGPUUU3TZX1YHFDBCPRTWBYIER14LT0' # your Foursquare ID
CLIENT_SECRET = '5FK1MXUWKERD2QHE2KJI0CRAM22CLUMA4BNPQRS5YIXOPGZJ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 10000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: LBN0SGLPFK3PPF2BRSGPUUU3TZX1YHFDBCPRTWBYIER14LT0
# CLIENT_SECRET:5FK1MXUWKERD2QHE2KJI0CRAM22CLUMA4BNPQRS5YIXOPGZJ

# %%
address = '100 Queen St W, Toronto, ON M5H 2N2'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6536032 -79.38400547469666

# %%
search_query = 'Park'
radius = 20000
print(search_query + ' .... OK!')
# Out:
# Park .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=LBN0SGLPFK3PPF2BRSGPUUU3TZX1YHFDBCPRTWBYIER14LT0&client_secret=5FK1MXUWKERD2QHE2KJI0CRAM22CLUMA4BNPQRS5YIXOPGZJ&ll=43.6536032,-79.38400547469666&v=20180604&query=Park&radius=20000&limit=10000'

# %%
results = requests.get(url).json()
Park = results['response']['venues']

# %%
dataframe = pd.json_normalize(Park)
dataframe.head()
# Out:
#                          id                                name  \
# 0  4b170e47f964a5208cc123e3         Queen's Park Subway Station
# 1  4b54deadf964a520a3d027e3                         Grange Park
# 2  4b9d206bf964a520e69136e3                        Queen's Park
# 3  4bfc5019da7120a132df49fd   St. Andrews Playground / Dog Park
# 4  4b9177e4f964a520d2be33e3  TTC Streetcar #403 - Victoria park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...  v-1596173188    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1596173188    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1596173188    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1596173188    False
# 4  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...  v-1596173188    False
#
#            location.address      location.crossStreet  location.lat  \
# 0        691 University Ave             at College St     43.660006
# 1                       NaN                       NaN     43.652488
# 2           University Ave.         at Wellesley Ave.     43.663946
# 3  450 Adelaide Street West  Brant St & Adelaide St W     43.647388
# 4                       NaN                       NaN     43.650735
#
#    location.lng                            location.labeledLatLngs  \
# 0    -79.390272  [{'label': 'display', 'lat': 43.66000635700919...
# 1    -79.392053  [{'label': 'display', 'lat': 43.65248755299856...
# 2    -79.392180  [{'label': 'display', 'lat': 43.66394609897775...
# 3    -79.398752  [{'label': 'display', 'lat': 43.64738759338116...
# 4    -79.386921  [{'label': 'display', 'lat': 43.650735, 'lng':...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                873             M5G 2P1          CA       Toronto
# 1                659                 NaN          CA       Toronto
# 2               1326             M5R 2E8          CA       Toronto
# 3               1374                 NaN          CA       Toronto
# 4                396                 NaN          CA       Toronto
#
#   location.state location.country  \
# 0             ON           Canada
# 1             ON           Canada
# 2             ON           Canada
# 3             ON           Canada
# 4             ON           Canada
#
#                            location.formattedAddress venuePage.id
# 0  [691 University Ave (at College St), Toronto O...          NaN
# 1  [btwn College, University, Queen & Spadina, To...          NaN
# 2  [University Ave. (at Wellesley Ave.), Toronto ...          NaN
# 3  [450 Adelaide Street West (Brant St & Adelaide...          NaN
# 4                               [Toronto ON, Canada]          NaN

# %%
df1 = dataframe[dataframe['location.city'] == 'Toronto']
df1.head()
# Out:
#                          id                                name  \
# 0  4b170e47f964a5208cc123e3         Queen's Park Subway Station
# 1  4b54deadf964a520a3d027e3                         Grange Park
# 2  4b9d206bf964a520e69136e3                        Queen's Park
# 3  4bfc5019da7120a132df49fd   St. Andrews Playground / Dog Park
# 4  4b9177e4f964a520d2be33e3  TTC Streetcar #403 - Victoria park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...  v-1596173188    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1596173188    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1596173188    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1596173188    False
# 4  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...  v-1596173188    False
#
#            location.address      location.crossStreet  location.lat  \
# 0        691 University Ave             at College St     43.660006
# 1                       NaN                       NaN     43.652488
# 2           University Ave.         at Wellesley Ave.     43.663946
# 3  450 Adelaide Street West  Brant St & Adelaide St W     43.647388
# 4                       NaN                       NaN     43.650735
#
#    location.lng                            location.labeledLatLngs  \
# 0    -79.390272  [{'label': 'display', 'lat': 43.66000635700919...
# 1    -79.392053  [{'label': 'display', 'lat': 43.65248755299856...
# 2    -79.392180  [{'label': 'display', 'lat': 43.66394609897775...
# 3    -79.398752  [{'label': 'display', 'lat': 43.64738759338116...
# 4    -79.386921  [{'label': 'display', 'lat': 43.650735, 'lng':...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                873             M5G 2P1          CA       Toronto
# 1                659                 NaN          CA       Toronto
# 2               1326             M5R 2E8          CA       Toronto
# 3               1374                 NaN          CA       Toronto
# 4                396                 NaN          CA       Toronto
#
#   location.state location.country  \
# 0             ON           Canada
# 1             ON           Canada
# 2             ON           Canada
# 3             ON           Canada
# 4             ON           Canada
#
#                            location.formattedAddress venuePage.id
# 0  [691 University Ave (at College St), Toronto O...          NaN
# 1  [btwn College, University, Queen & Spadina, To...          NaN
# 2  [University Ave. (at Wellesley Ave.), Toronto ...          NaN
# 3  [450 Adelaide Street West (Brant St & Adelaide...          NaN
# 4                               [Toronto ON, Canada]          NaN

# %%
df1.columns
# Out:
# Index(['id', 'name', 'categories', 'referralId', 'hasPerk', 'location.address',
#        'location.crossStreet', 'location.lat', 'location.lng',
#        'location.labeledLatLngs', 'location.distance', 'location.postalCode',
#        'location.cc', 'location.city', 'location.state', 'location.country',
#        'location.formattedAddress', 'venuePage.id'],
#       dtype='object')

# %%
df_park = df1.drop(['name','categories','referralId', 'hasPerk', 'location.address','location.crossStreet','location.labeledLatLngs','location.distance','location.postalCode','location.cc','location.city','location.state','location.country','location.formattedAddress','venuePage.id'], axis=1)
df_park
# Out:
#                           id  location.lat  location.lng
# 0   4b170e47f964a5208cc123e3     43.660006    -79.390272
# 1   4b54deadf964a520a3d027e3     43.652488    -79.392053
# 2   4b9d206bf964a520e69136e3     43.663946    -79.392180
# 3   4bfc5019da7120a132df49fd     43.647388    -79.398752
# 4   4b9177e4f964a520d2be33e3     43.650735    -79.386921
# 5   4ad80fcef964a520a61021e3     43.655442    -79.390056
# 6   4bb79860cf2fc9b616779e02     43.648048    -79.375172
# 7   59f1fde348b04e1a8368f4f4     43.659240    -79.382860
# 8   4ba5a1e2f964a5202b1839e3     43.669951    -79.355493
# 9   4d3a1d23325ff04db2dd1845     43.659822    -79.385159
# 10  4b797b48f964a520c6fb2ee3     43.653610    -79.402199
# 11  4ad4c05ef964a520bdf620e3     43.647072    -79.413756
# 12  59ddd7469ba3e51a75459568     43.659263    -79.382632
# 13  4ca32b95a73cb60cc61f1678     43.660009    -79.383905
# 14  4bb3c91a2397b7134d9f38b3     43.644222    -79.394230
# 15  4b618500f964a52090162ae3     43.637949    -79.387820
# 16  4bb63b82941ad13a5e181fe3     43.666048    -79.360941
# 17  4b7ddd79f964a52014d82fe3     43.648963    -79.364868
# 18  4c030bf9f423a5938bc3cf16     43.666879    -79.381068
# 19  4c54aeb330f92d7f73b8daba     43.655337    -79.371923
# 20  4bdde5056198c9b61a1c12ff     43.638762    -79.397067
# 21  537feaf9498e871d4bd5e016     43.666728    -79.381084
# 22  4f7791e5e4b0421082eeacb6     43.660009    -79.364191
# 23  4b9c2ef4f964a520785236e3     43.642395    -79.409330
# 24  4b9333f1f964a520fa3a34e3     43.634553    -79.405403
# 25  4ad4c05ef964a5209ff620e3     43.646479    -79.463425
# 26  53a4b638498edce8c3153b44     43.660383    -79.361810
# 27  4b23bce0f964a520ce5824e3     43.666583    -79.380040
# 28  4e54574bb61c93816c084ddb     43.654654    -79.362501
# 29  4adb5deef964a5207d2621e3     43.634180    -79.323671
# 30  537b7f9e498e48d2ddf48326     43.659512    -79.363048
# 31  4e0ce37c8877c535e47259be     43.639748    -79.395978
# 32  4cf2553c6c29236a20fd6aa2     43.668849    -79.394460
# 33  4c34e9f7a0ced13a96fb186e     43.641668    -79.409269
# 34  4c16a548955976b0cadea4f6     43.650264    -79.362195
# 36  4bb606111344b71388da9c04     43.666231    -79.371631
# 37  4bc33d5cabf495217170c393     43.670186    -79.391180
# 39  52216b03498e1ee04c75aeb0     43.655396    -79.412673
# 40  4c17a3cec2dfc9281350a869     43.659572    -79.365759
# 41  4fc61a72e4b0bf27802f1a33     43.659198    -79.382863
# 42  4afa3d22f964a520761722e3     43.639024    -79.415510
# 43  4bbd2aff8a4fb7130ebc3c9d     43.683732    -79.409881
# 44  559dd766498e3287c7c0db6a     43.660282    -79.361181
# 45  4cf86dd04464b60c7f8160f8     43.643577    -79.421429
# 46  4b68ed27f964a52086932be3     43.661237    -79.383603
# 48  557f24f6498e5325baa2a8c4     43.654224    -79.381882

# %%
from sklearn.cluster import KMeans 
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler
X = df_park.values[:,1:]
X = np.nan_to_num(X)
Clus_dataSet = StandardScaler().fit_transform(X)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
clusterNum = 5
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
labels = k_means.labels_
print(labels)
# Out:
# [3 3 3 1 3 3 0 3 0 3 1 1 3 3 1 1 0 0 3 0 1 3 0 1 1 2 0 3 0 4 0 1 3 1 0 0 3
#  1 0 3 1 3 0 1 3 3]

# %%
df_park['Cluster Labels'] = labels
df_park['name']= dataframe['name']
df_park
# Out:
#                           id  location.lat  location.lng  Cluster Labels  \
# 0   4b170e47f964a5208cc123e3     43.660006    -79.390272               3
# 1   4b54deadf964a520a3d027e3     43.652488    -79.392053               3
# 2   4b9d206bf964a520e69136e3     43.663946    -79.392180               3
# 3   4bfc5019da7120a132df49fd     43.647388    -79.398752               1
# 4   4b9177e4f964a520d2be33e3     43.650735    -79.386921               3
# 5   4ad80fcef964a520a61021e3     43.655442    -79.390056               3
# 6   4bb79860cf2fc9b616779e02     43.648048    -79.375172               0
# 7   59f1fde348b04e1a8368f4f4     43.659240    -79.382860               3
# 8   4ba5a1e2f964a5202b1839e3     43.669951    -79.355493               0
# 9   4d3a1d23325ff04db2dd1845     43.659822    -79.385159               3
# 10  4b797b48f964a520c6fb2ee3     43.653610    -79.402199               1
# 11  4ad4c05ef964a520bdf620e3     43.647072    -79.413756               1
# 12  59ddd7469ba3e51a75459568     43.659263    -79.382632               3
# 13  4ca32b95a73cb60cc61f1678     43.660009    -79.383905               3
# 14  4bb3c91a2397b7134d9f38b3     43.644222    -79.394230               1
# 15  4b618500f964a52090162ae3     43.637949    -79.387820               1
# 16  4bb63b82941ad13a5e181fe3     43.666048    -79.360941               0
# 17  4b7ddd79f964a52014d82fe3     43.648963    -79.364868               0
# 18  4c030bf9f423a5938bc3cf16     43.666879    -79.381068               3
# 19  4c54aeb330f92d7f73b8daba     43.655337    -79.371923               0
# 20  4bdde5056198c9b61a1c12ff     43.638762    -79.397067               1
# 21  537feaf9498e871d4bd5e016     43.666728    -79.381084               3
# 22  4f7791e5e4b0421082eeacb6     43.660009    -79.364191               0
# 23  4b9c2ef4f964a520785236e3     43.642395    -79.409330               1
# 24  4b9333f1f964a520fa3a34e3     43.634553    -79.405403               1
# 25  4ad4c05ef964a5209ff620e3     43.646479    -79.463425               2
# 26  53a4b638498edce8c3153b44     43.660383    -79.361810               0
# 27  4b23bce0f964a520ce5824e3     43.666583    -79.380040               3
# 28  4e54574bb61c93816c084ddb     43.654654    -79.362501               0
# 29  4adb5deef964a5207d2621e3     43.634180    -79.323671               4
# 30  537b7f9e498e48d2ddf48326     43.659512    -79.363048               0
# 31  4e0ce37c8877c535e47259be     43.639748    -79.395978               1
# 32  4cf2553c6c29236a20fd6aa2     43.668849    -79.394460               3
# 33  4c34e9f7a0ced13a96fb186e     43.641668    -79.409269               1
# 34  4c16a548955976b0cadea4f6     43.650264    -79.362195               0
# 36  4bb606111344b71388da9c04     43.666231    -79.371631               0
# 37  4bc33d5cabf495217170c393     43.670186    -79.391180               3
# 39  52216b03498e1ee04c75aeb0     43.655396    -79.412673               1
# 40  4c17a3cec2dfc9281350a869     43.659572    -79.365759               0
# 41  4fc61a72e4b0bf27802f1a33     43.659198    -79.382863               3
# 42  4afa3d22f964a520761722e3     43.639024    -79.415510               1
# 43  4bbd2aff8a4fb7130ebc3c9d     43.683732    -79.409881               3
# 44  559dd766498e3287c7c0db6a     43.660282    -79.361181               0
# 45  4cf86dd04464b60c7f8160f8     43.643577    -79.421429               1
# 46  4b68ed27f964a52086932be3     43.661237    -79.383603               3
# 48  557f24f6498e5325baa2a8c4     43.654224    -79.381882               3
#
#                                            name
# 0                   Queen's Park Subway Station
# 1                                   Grange Park
# 2                                  Queen's Park
# 3             St. Andrews Playground / Dog Park
# 4            TTC Streetcar #403 - Victoria park
# 5                                 One Park Lane
# 6                                   Berczy Park
# 7                        Physiomed College Park
# 8                           Riverdale Park East
# 9              Residences at College Park North
# 10                         Bellevue Square Park
# 11                       Trinity Bellwoods Park
# 12                Crunch Fitness - College Park
# 13             Toothworks - College Park Dental
# 14                         Clarence Square Park
# 15                                     HTO Park
# 16                          Riverdale Park West
# 17                      St Lawrence on the Park
# 18                            Barbara Hall Park
# 19                      Moss Park Tennis Courts
# 20                           Canoe Landing Park
# 21                            Barbara Hall Park
# 22                                  Regent Park
# 23                                 Stanley Park
# 24                              Coronation Park
# 25                                    High Park
# 26                                  Regent Park
# 27                      Cawthra Square Dog Park
# 28                 Orphan's Greenspace Dog Park
# 29                          Tommy Thompson Park
# 30                 Regent Park Community Centre
# 31                Dog Park - Canoe Landing Park
# 32                      Park Hyatt Bridal Suite
# 33                      Stanley Park (Dog Park)
# 34                       Parliament Square Park
# 36                              Winchester Park
# 37                    Village of Yorkville Park
# 39                                  Weldon Park
# 40          Regent Park Community Health Centre
# 41                         Aura at College Park
# 42                           Battery Park Tower
# 43                   Sir Winston Churchill Park
# 44  Club UNO - One Park Place - Amenities Space
# 45                       Paul E. Garfinkel Park
# 46                                 College Park
# 48                   Trinity Park And Labyrinth

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

kclusters = 5

# create map
map_clusters = folium.Map(location=[43.6536032, -79.38400547469666], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_park['location.lat'], df_park['location.lng'], df_park['name'], df_park['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_park.loc[df_park['Cluster Labels']==0]
# Out:
#                           id  location.lat  location.lng  Cluster Labels  \
# 6   4bb79860cf2fc9b616779e02     43.648048    -79.375172               0
# 8   4ba5a1e2f964a5202b1839e3     43.669951    -79.355493               0
# 16  4bb63b82941ad13a5e181fe3     43.666048    -79.360941               0
# 17  4b7ddd79f964a52014d82fe3     43.648963    -79.364868               0
# 19  4c54aeb330f92d7f73b8daba     43.655337    -79.371923               0
# 22  4f7791e5e4b0421082eeacb6     43.660009    -79.364191               0
# 26  53a4b638498edce8c3153b44     43.660383    -79.361810               0
# 28  4e54574bb61c93816c084ddb     43.654654    -79.362501               0
# 30  537b7f9e498e48d2ddf48326     43.659512    -79.363048               0
# 34  4c16a548955976b0cadea4f6     43.650264    -79.362195               0
# 36  4bb606111344b71388da9c04     43.666231    -79.371631               0
# 40  4c17a3cec2dfc9281350a869     43.659572    -79.365759               0
# 44  559dd766498e3287c7c0db6a     43.660282    -79.361181               0
#
#                                            name
# 6                                   Berczy Park
# 8                           Riverdale Park East
# 16                          Riverdale Park West
# 17                      St Lawrence on the Park
# 19                      Moss Park Tennis Courts
# 22                                  Regent Park
# 26                                  Regent Park
# 28                 Orphan's Greenspace Dog Park
# 30                 Regent Park Community Centre
# 34                       Parliament Square Park
# 36                              Winchester Park
# 40          Regent Park Community Health Centre
# 44  Club UNO - One Park Place - Amenities Space

# %%
df_park.loc[df_park['Cluster Labels']==1]
# Out:
#                           id  location.lat  location.lng  Cluster Labels  \
# 3   4bfc5019da7120a132df49fd     43.647388    -79.398752               1
# 10  4b797b48f964a520c6fb2ee3     43.653610    -79.402199               1
# 11  4ad4c05ef964a520bdf620e3     43.647072    -79.413756               1
# 14  4bb3c91a2397b7134d9f38b3     43.644222    -79.394230               1
# 15  4b618500f964a52090162ae3     43.637949    -79.387820               1
# 20  4bdde5056198c9b61a1c12ff     43.638762    -79.397067               1
# 23  4b9c2ef4f964a520785236e3     43.642395    -79.409330               1
# 24  4b9333f1f964a520fa3a34e3     43.634553    -79.405403               1
# 31  4e0ce37c8877c535e47259be     43.639748    -79.395978               1
# 33  4c34e9f7a0ced13a96fb186e     43.641668    -79.409269               1
# 39  52216b03498e1ee04c75aeb0     43.655396    -79.412673               1
# 42  4afa3d22f964a520761722e3     43.639024    -79.415510               1
# 45  4cf86dd04464b60c7f8160f8     43.643577    -79.421429               1
#
#                                  name
# 3   St. Andrews Playground / Dog Park
# 10               Bellevue Square Park
# 11             Trinity Bellwoods Park
# 14               Clarence Square Park
# 15                           HTO Park
# 20                 Canoe Landing Park
# 23                       Stanley Park
# 24                    Coronation Park
# 31      Dog Park - Canoe Landing Park
# 33            Stanley Park (Dog Park)
# 39                        Weldon Park
# 42                 Battery Park Tower
# 45             Paul E. Garfinkel Park

# %%
df_park.loc[df_park['Cluster Labels']==2]
# Out:
#                           id  location.lat  location.lng  Cluster Labels  \
# 25  4ad4c05ef964a5209ff620e3     43.646479    -79.463425               2
#
#          name
# 25  High Park

# %%
df_park.loc[df_park['Cluster Labels']==3]
# Out:
#                           id  location.lat  location.lng  Cluster Labels  \
# 0   4b170e47f964a5208cc123e3     43.660006    -79.390272               3
# 1   4b54deadf964a520a3d027e3     43.652488    -79.392053               3
# 2   4b9d206bf964a520e69136e3     43.663946    -79.392180               3
# 4   4b9177e4f964a520d2be33e3     43.650735    -79.386921               3
# 5   4ad80fcef964a520a61021e3     43.655442    -79.390056               3
# 7   59f1fde348b04e1a8368f4f4     43.659240    -79.382860               3
# 9   4d3a1d23325ff04db2dd1845     43.659822    -79.385159               3
# 12  59ddd7469ba3e51a75459568     43.659263    -79.382632               3
# 13  4ca32b95a73cb60cc61f1678     43.660009    -79.383905               3
# 18  4c030bf9f423a5938bc3cf16     43.666879    -79.381068               3
# 21  537feaf9498e871d4bd5e016     43.666728    -79.381084               3
# 27  4b23bce0f964a520ce5824e3     43.666583    -79.380040               3
# 32  4cf2553c6c29236a20fd6aa2     43.668849    -79.394460               3
# 37  4bc33d5cabf495217170c393     43.670186    -79.391180               3
# 41  4fc61a72e4b0bf27802f1a33     43.659198    -79.382863               3
# 43  4bbd2aff8a4fb7130ebc3c9d     43.683732    -79.409881               3
# 46  4b68ed27f964a52086932be3     43.661237    -79.383603               3
# 48  557f24f6498e5325baa2a8c4     43.654224    -79.381882               3
#
#                                   name
# 0          Queen's Park Subway Station
# 1                          Grange Park
# 2                         Queen's Park
# 4   TTC Streetcar #403 - Victoria park
# 5                        One Park Lane
# 7               Physiomed College Park
# 9     Residences at College Park North
# 12       Crunch Fitness - College Park
# 13    Toothworks - College Park Dental
# 18                   Barbara Hall Park
# 21                   Barbara Hall Park
# 27             Cawthra Square Dog Park
# 32             Park Hyatt Bridal Suite
# 37           Village of Yorkville Park
# 41                Aura at College Park
# 43          Sir Winston Churchill Park
# 46                        College Park
# 48          Trinity Park And Labyrinth

# %%
df_park.loc[df_park['Cluster Labels']==4]
# Out:
#                           id  location.lat  location.lng  Cluster Labels  \
# 29  4adb5deef964a5207d2621e3      43.63418    -79.323671               4
#
#                    name
# 29  Tommy Thompson Park

# %%
df_place = df_park.loc[df_park['Cluster Labels']==3]
df_place.mean()
# Out:
# location.lat      43.662143
# location.lng     -79.387339
# Cluster Labels     3.000000
# dtype: float64

# %%
sanfran_map = folium.Map(location=[43.662143, -79.387339], zoom_start=15)

incidents = folium.map.FeatureGroup()


incidents.add_child(
        folium.features.CircleMarker(
            [43.662143, -79.387339],
            radius=50, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

folium.Marker([43.662143, -79.387339], popup=label).add_to(sanfran_map)    
    
# add incidents to map
sanfran_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
